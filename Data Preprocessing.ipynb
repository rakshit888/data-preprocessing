# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns

# %%
os.chdir(r'C:\Users\HP\Desktop')

# %%
dataset1=pd.read_csv('Employee.csv')

# %%
 dataset=dataset1.iloc[:,0:7]

# %%
dataset
# Out:
#     Employee Id First Name   Last Name           Department   Age  Experience  \
# 0             1        Joy        Bass  Sales and Marketing  28.0         3.0
# 1             2     Sheila       Garza  Sales and Marketing  22.0         1.0
# 2             3       John      Bryant   Customer Relations  22.0         1.0
# 3             4  Christian      Farley   Customer Relations  22.0         1.0
# 4             5   Colorado       Bowen           Accounting  27.0         0.0
# 5             6     Elijah    Matthews           Accounting  26.0         5.0
# 6             7         Bo      Mcleod   Customer Relations  24.0         6.0
# 7             8       Zena    Melendez   Customer Relations  29.0         2.0
# 8             9     Tucker     Michael  Sales and Marketing  29.0         5.0
# 9            10      Lucas        Rowe   Customer Relations  30.0         6.0
# 10           11    Mallory      Walker           Accounting  26.0         5.0
# ...

# %%
len(dataset)
# Out:
# 100

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
# Employee Id    100 non-null int64
# First Name     100 non-null object
# Last Name      100 non-null object
# Department     81 non-null object
# Age            82 non-null float64
# Experience     90 non-null float64
# Salary         100 non-null int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.5+ KB

# %%
dataset.isnull().sum()
# Out:
# Employee Id     0
# First Name      0
# Last Name       0
# Department     19
# Age            18
# Experience     10
# Salary          0
# dtype: int64

# %%
sns.boxplot(data = dataset, y='Age')

# %%
sns.boxplot(data = dataset, y='Experience')

# %%
x = dataset.iloc[ : ,3:6].values

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %% [markdown]
# # missing value treatment

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = 'NaN',strategy='median',axis=0)
imputer = imputer.fit(x[:,1:3])
x[:,1:3] = imputer.transform(x[:,1:3])
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 16.5],
#        ['Customer Relations', 22.0, 16.5],
#        ['Accounting', 25.0, 16.5],
#        ['Accounting', 27.0, 16.5],
#        [nan, 25.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 24.0, 16.5],
#        [nan, 27.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 33.0, 13.0],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = 'NaN',strategy='mean',axis=0)
imputer = imputer.fit(x[:,1:3])
x[:,1:3] = imputer.transform(x[:,1:3])
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 16.5],
#        ['Customer Relations', 22.0, 16.5],
#        ['Accounting', 25.0, 16.5],
#        ['Accounting', 27.0, 16.5],
#        [nan, 25.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 24.0, 16.5],
#        [nan, 27.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 33.0, 13.0],
# ...

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='most_frequent')

# %%
imputer = imputer.fit(x[:,0:1])
x[:,0:1] = imputer.transform(x[:,0:1])

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 16.5],
#        ['Customer Relations', 22.0, 16.5],
#        ['Accounting', 25.0, 16.5],
#        ['Accounting', 27.0, 16.5],
#        ['Sales and Marketing', 25.0, 16.5],
#        ['Sales and Marketing', 22.0, 16.5],
#        ['Sales and Marketing', 22.0, 16.5],
#        ['Sales and Marketing', 24.0, 16.5],
# ...

# %%
dataset.groupby('Department').size()
# Out:
# Department
# Accounting             27
# Customer Relations     24
# Sales and Marketing    30
# dtype: int64

# %%
type(x)
# Out:
# numpy.ndarray

# %%
dataset_2=dataset

# %%
dataset_2['Department']=dataset_2['Department'].fillna('Sales and Marketing')

# %%
dataset_2['Age']=dataset_2['Age'].fillna(dataset_2['Age'].mean())

# %%
dataset_2['Experience']=dataset_2['Experience'].fillna(dataset_2['Experience'].mean())

# %%
dataset_2
# Out:
#     Employee Id First Name   Last Name           Department   Age  Experience  \
# 0             1        Joy        Bass  Sales and Marketing  28.0    3.000000
# 1             2     Sheila       Garza  Sales and Marketing  22.0    1.000000
# 2             3       John      Bryant   Customer Relations  22.0    1.000000
# 3             4  Christian      Farley   Customer Relations  22.0    1.000000
# 4             5   Colorado       Bowen           Accounting  27.0    0.000000
# 5             6     Elijah    Matthews           Accounting  26.0    5.000000
# 6             7         Bo      Mcleod   Customer Relations  24.0    6.000000
# 7             8       Zena    Melendez   Customer Relations  29.0    2.000000
# 8             9     Tucker     Michael  Sales and Marketing  29.0    5.000000
# 9            10      Lucas        Rowe   Customer Relations  30.0    6.000000
# 10           11    Mallory      Walker           Accounting  26.0    5.000000
# ...

# %%
database=pd.read_csv('Outlier_data.csv')

# %%
database
# Out:
#   Department  Age  Experience
# 0         HR   21           1
# 1         HR   33          12
# 2         IT   35          12
# 3         IT   36          12
# 4         HR   34          11
# 5         IT   33          13
# 6  Marketing   34          12
# 7         HR   32          10
# 8  Marketing   31           2
# 9         IT   55          35

# %%
Q1 = database.quantile(0.25)
Q3 = database.quantile(0.75)

# %%
Q1
# Out:
# Age           32.25
# Experience    10.25
# Name: 0.25, dtype: float64

# %%
Q3
# Out:
# Age           34.75
# Experience    12.00
# Name: 0.75, dtype: float64

# %%
IQR =Q3 - Q1

# %%
IQR
# Out:
# Age           2.50
# Experience    1.75
# dtype: float64

# %%
database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
# Department    10 non-null object
# Age           10 non-null int64
# Experience    10 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 320.0+ bytes

# %%
database['Department'] = database['Department'].astype('category')
database['Department'] = database['Department'].cat.codes

# %%
database
# Out:
#    Department  Age  Experience
# 0           0   21           1
# 1           0   33          12
# 2           1   35          12
# 3           1   36          12
# 4           0   34          11
# 5           1   33          13
# 6           2   34          12
# 7           0   32          10
# 8           2   31           2
# 9           1   55          35

# %%
database[~((database < (Q1 - 1.5*IQR))| (database> (Q3 + 1.5*IQR))).any(axis=1)]
# Out:
#    Department  Age  Experience
# 1           0   33          12
# 2           1   35          12
# 3           1   36          12
# 4           0   34          11
# 5           1   33          13
# 6           2   34          12
# 7           0   32          10

# %%
database[((database < (Q1 - 1.5*IQR))| (database> (Q3 + 1.5*IQR))).any(axis=1)]
# Out:
#    Department  Age  Experience
# 0           0   21           1
# 8           2   31           2
# 9           1   55          35

# %% [markdown]
# # Encoding Categorical Data

# %%
data = pd.read_csv('Preprocessing.csv')

# %%
data
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   45   61000        No
# 4  Germany   40   45000       Yes
# 5   France   35   58000       Yes
# 6    Spain   39   52000        No
# 7   France   48   79000       Yes
# 8  Germany   50   83000        No
# 9   France   37   67000       Yes

# %%
x = data.iloc[:,0:3].values

# %%
x
# Out:
# array([['France', 44, 72000],
#        ['Spain', 27, 48000],
#        ['Germany', 30, 54000],
#        ['Spain', 45, 61000],
#        ['Germany', 40, 45000],
#        ['France', 35, 58000],
#        ['Spain', 39, 52000],
#        ['France', 48, 79000],
#        ['Germany', 50, 83000],
#        ['France', 37, 67000]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_x = LabelEncoder()
x[:,0] = labelencoder_x.fit_transform(x[:,0])

# %%
x
# Out:
# array([[0, 44, 72000],
#        [2, 27, 48000],
#        [1, 30, 54000],
#        [2, 45, 61000],
#        [1, 40, 45000],
#        [0, 35, 58000],
#        [2, 39, 52000],
#        [0, 48, 79000],
#        [1, 50, 83000],
#        [0, 37, 67000]], dtype=object)

# %%
onehotencoder = OneHotEncoder(categorical_features=[0])
x = onehotencoder.fit_transform(x).toarray()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
x
# Out:
# array([[1.0e+00, 0.0e+00, 0.0e+00, 4.4e+01, 7.2e+04],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.7e+01, 4.8e+04],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.0e+01, 5.4e+04],
#        [0.0e+00, 0.0e+00, 1.0e+00, 4.5e+01, 6.1e+04],
#        [0.0e+00, 1.0e+00, 0.0e+00, 4.0e+01, 4.5e+04],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.5e+01, 5.8e+04],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.9e+01, 5.2e+04],
#        [1.0e+00, 0.0e+00, 0.0e+00, 4.8e+01, 7.9e+04],
#        [0.0e+00, 1.0e+00, 0.0e+00, 5.0e+01, 8.3e+04],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.7e+01, 6.7e+04]])

# %%
pd.DataFrame(x)
# Out:
#      0    1    2     3        4
# 0  1.0  0.0  0.0  44.0  72000.0
# 1  0.0  0.0  1.0  27.0  48000.0
# 2  0.0  1.0  0.0  30.0  54000.0
# 3  0.0  0.0  1.0  45.0  61000.0
# 4  0.0  1.0  0.0  40.0  45000.0
# 5  1.0  0.0  0.0  35.0  58000.0
# 6  0.0  0.0  1.0  39.0  52000.0
# 7  1.0  0.0  0.0  48.0  79000.0
# 8  0.0  1.0  0.0  50.0  83000.0
# 9  1.0  0.0  0.0  37.0  67000.0

# %% [markdown]
# # Feature scailing

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_stand = sc_x.fit_transform(x)

# %%
pd.DataFrame(x_stand)
# Out:
#           0         1         2         3         4
# 0  1.224745 -0.654654 -0.654654  0.632299  0.818976
# 1 -0.816497 -0.654654  1.527525 -1.756387 -1.127105
# 2 -0.816497  1.527525 -0.654654 -1.334854 -0.640585
# 3 -0.816497 -0.654654  1.527525  0.772810 -0.072978
# 4 -0.816497  1.527525 -0.654654  0.070255 -1.370365
# 5  1.224745 -0.654654 -0.654654 -0.632299 -0.316238
# 6 -0.816497 -0.654654  1.527525 -0.070255 -0.802758
# 7  1.224745 -0.654654 -0.654654  1.194343  1.386583
# 8 -0.816497  1.527525 -0.654654  1.475365  1.710930
# 9  1.224745 -0.654654 -0.654654 -0.351277  0.413542

# %%
from sklearn.preprocessing import Normalizer
nm_x = Normalizer()
x_norm = nm_x.fit_transform(x)

# %%
pd.DataFrame(x_norm)
# Out:
#           0         1         2         3    4
# 0  0.000014  0.000000  0.000000  0.000611  1.0
# 1  0.000000  0.000000  0.000021  0.000562  1.0
# 2  0.000000  0.000019  0.000000  0.000556  1.0
# 3  0.000000  0.000000  0.000016  0.000738  1.0
# 4  0.000000  0.000022  0.000000  0.000889  1.0
# 5  0.000017  0.000000  0.000000  0.000603  1.0
# 6  0.000000  0.000000  0.000019  0.000750  1.0
# 7  0.000013  0.000000  0.000000  0.000608  1.0
# 8  0.000000  0.000012  0.000000  0.000602  1.0
# 9  0.000015  0.000000  0.000000  0.000552  1.0
